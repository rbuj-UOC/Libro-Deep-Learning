# %% [markdown]
# <div style="width: 100%; clear: both;">
#     <div style="float: left; width: 50%;">
#         <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
#     </div>
#     <div style="float: right; width: 50%;">
#         <p style="margin: 0; padding-top: 22px; text-align:right;">M2.875 - Deep Learning</p>
#         <p style="margin: 0; text-align:right;">Estudios de Informática, Multimedia y Telecomunicación</p>
#         <p style="margin: 0; text-align:right; padding-button: 100px;">Universitat Oberta de Catalunya (UOC)</p>
#     </div>
# </div>
# <div style="width:100%;">&nbsp;</div>

# %% [markdown]
# # Ejemplo de funcionamiento de Autoencoder
#
# En este ejemplo veremos un caso de aplicación para un autoencoder. En concreto, nos centraremos en la compresión y reconstrucción de imágenes empleando *autoencoders*.
#
# <u>Nota</u>: Este ejemplo está basado en https://blog.keras.io/building-autoencoders-in-keras.html

# %% [markdown]
# Deshabilitamos la aparición de warnings.
#
# <u>Nota</u>: No se recomienda este paso cuando se está desarrollando el código.

# %%
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Carga de las librerías
#
# Carga de las librerías para ejecutar el ejemplo.

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

keras_version = getattr(keras, "__version__", None)
if keras_version is None:
    try:
        from importlib.metadata import version

        keras_version = version("keras")
    except Exception:
        keras_version = "no disponible"

print("TensorFlow version: {}".format(tf.__version__))
print("Keras version     : {}".format(keras_version))
print("Numpy version     : {}".format(np.__version__))
# Out:
# TensorFlow version: 2.15.1
# Keras version     : 2.15.0
# Numpy version     : 1.26.4

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Carga del conjunto de datos
#
# En primer lugar, cargamos el conjunto de datos, que en este caso será el dataset de dígitos [MNIST](https://en.wikipedia.org/wiki/MNIST_database).
#
# Realizamos esta carga, directamente, a partir de la librería [Keras](https://keras.io/).

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# ## 2. Creación del *autoencoder*
#
# A continuación, creamos el *autoencoder* en su forma más senzilla:
# - A partir de las imágenes de entrada de de 28x28 píxeles en escala de grises, se crea una capa con 784 valores de entrada
# - Creamos un **codificador** (*encoder*) con una representación de 32 neuronas
# - Creamos un **decodificador** (*decoder*) que genere una salida en la misma resolución que las imágenes de entrada, es decir, 784 neuronas de salida para generar una imagen de 28x28 píxeles en escala de grises.

# %%
from keras.layers import Input, Dense
from keras.models import Model

# Tamaño de la representación interna del autoencoder
layer1dim = 64
layer2dim = 32
layer3dim = 64

# capa de entrada
input_img = Input(shape=(784,))
# representación interna (encoded)
h1 = Dense(layer1dim, activation="relu")(input_img)
h2 = Dense(layer2dim, activation="relu")(h1)
h3 = Dense(layer3dim, activation="relu")(h2)

# salida del autoencoder, es decir, la imagen reconstruida (decoded)
decoded = Dense(784, activation="sigmoid")(h3)

# el modelo completo de autoencoder, que apila la entrada y la salida
autoencoder = Model(input_img, decoded)

# %% [markdown]
# Para finalidades didácticas, definimos el modelo `encoder` que genera la codificación interna del autoencoder, sin el proceso de decodificación.

# %%
# este modelo crea la representación interna
encoder = Model(input_img, h3)

encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 64)                50240
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 64)                2112
#
# =================================================================
# Total params: 54432 (212.62 KB)
# Trainable params: 54432 (212.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# De forma similar, definimos el modelo `decoder` que a partir de la representación interna (32 valores) reconstruye la imagen, es decir, aplica el proceso de decodificación.

# %%
# capa de entrada de la representación interna
encoded_input = Input(shape=(layer1dim,))

# obtener la última capa del autoencoder definido previamente
decoder_layer = autoencoder.layers[-1]

# creación del modelo
decoder = Model(encoded_input, decoder_layer(encoded_input))

decoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64)]              0
#
#  dense_3 (Dense)             (None, 784)               50960
#
# =================================================================
# Total params: 50960 (199.06 KB)
# Trainable params: 50960 (199.06 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Finalmente, definimos el optimizador y la función de pérdida empleada para el entrenamiento del *autoencoder*.

# %%
autoencoder.compile(loss="binary_crossentropy", optimizer=tf.keras.optimizers.legacy.SGD(learning_rate=1.5))
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 64)                50240
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 64)                2112
#
#  dense_3 (Dense)             (None, 784)               50960
#
# =================================================================
# Total params: 105392 (411.69 KB)
# Trainable params: 105392 (411.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 3. Entrenamiento del *autoencoder*
#
# En el siguiente fragmento de código se entrena el *autoencoder* creado anteriormente.
#
# Los hiperparámetros para ajustar el entrenamiento, además del optimizador y función de pérdida, son:
# - número de épocas del entrenamiento
# - tamaño del lote

# %%
n_epochs = 50
n_batch_size = 256

# %%
mfit = autoencoder.fit(
    x_train,
    x_train,
    epochs=n_epochs,
    batch_size=n_batch_size,
    shuffle=True,
    validation_data=(x_test, x_test),
)
# Out:
# Epoch 1/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.3045 - val_loss: 0.2606
# Epoch 2/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.2437 - val_loss: 0.2210
# Epoch 3/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.2070 - val_loss: 0.1955
# Epoch 4/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1893 - val_loss: 0.1810
# Epoch 5/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1767 - val_loss: 0.1728
# Epoch 6/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1663 - val_loss: 0.1581
# Epoch 7/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1588 - val_loss: 0.1526
# Epoch 8/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1533 - val_loss: 0.1512
# Epoch 9/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1491 - val_loss: 0.1431
# Epoch 10/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1451 - val_loss: 0.1409
# Epoch 11/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1416 - val_loss: 0.1364
# Epoch 12/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1381 - val_loss: 0.1335
# Epoch 13/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1349 - val_loss: 0.1344
# Epoch 14/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1323 - val_loss: 0.1298
# Epoch 15/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1300 - val_loss: 0.1298
# Epoch 16/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1285 - val_loss: 0.1268
# Epoch 17/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1266 - val_loss: 0.1265
# Epoch 18/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1251 - val_loss: 0.1220
# Epoch 19/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1237 - val_loss: 0.1212
# Epoch 20/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1224 - val_loss: 0.1195
# Epoch 21/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1212 - val_loss: 0.1166
# Epoch 22/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1201 - val_loss: 0.1198
# Epoch 23/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1193 - val_loss: 0.1177
# Epoch 24/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1184 - val_loss: 0.1147
# Epoch 25/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1173 - val_loss: 0.1142
# Epoch 26/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1167 - val_loss: 0.1124
# Epoch 27/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1158 - val_loss: 0.1129
# Epoch 28/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1150 - val_loss: 0.1139
# Epoch 29/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1143 - val_loss: 0.1120
# Epoch 30/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1137 - val_loss: 0.1124
# Epoch 31/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1130 - val_loss: 0.1113
# Epoch 32/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1124 - val_loss: 0.1133
# Epoch 33/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1118 - val_loss: 0.1098
# Epoch 34/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1110 - val_loss: 0.1092
# Epoch 35/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1105 - val_loss: 0.1098
# Epoch 36/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1097 - val_loss: 0.1083
# Epoch 37/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1091 - val_loss: 0.1087
# Epoch 38/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1085 - val_loss: 0.1059
# Epoch 39/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1079 - val_loss: 0.1063
# Epoch 40/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1074 - val_loss: 0.1066
# Epoch 41/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1067 - val_loss: 0.1053
# Epoch 42/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1063 - val_loss: 0.1069
# Epoch 43/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1058 - val_loss: 0.1040
# Epoch 44/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1054 - val_loss: 0.1045
# Epoch 45/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1049 - val_loss: 0.1037
# Epoch 46/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1047 - val_loss: 0.1022
# Epoch 47/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1042 - val_loss: 0.1042
# Epoch 48/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1039 - val_loss: 0.1049
# Epoch 49/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1036 - val_loss: 0.1017
# Epoch 50/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1032 - val_loss: 0.1022

# %%
# Stacked Autoencoder with functional model
# encoder
inputs = keras.Input(shape=(28, 28))
lr_flatten = keras.layers.Flatten()(inputs)
lr1 = keras.layers.Dense(392, activation="selu")(lr_flatten)
lr2 = keras.layers.Dense(196, activation="selu")(lr1)
# decoder
lr3 = keras.layers.Dense(392, activation="selu")(lr2)
lr4 = keras.layers.Dense(28 * 28, activation="sigmoid")(lr3)
outputs = keras.layers.Reshape([28, 28])(lr4)
stacked_ae = keras.models.Model(inputs, outputs)
stacked_ae.compile(loss="binary_crossentropy", optimizer=tf.keras.optimizers.legacy.SGD(learning_rate=1.5))
stacked_ae.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28)]          0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense_4 (Dense)             (None, 392)               307720
#
#  dense_5 (Dense)             (None, 196)               77028
#
#  dense_6 (Dense)             (None, 392)               77224
#
#  dense_7 (Dense)             (None, 784)               308112
#
#  reshape (Reshape)           (None, 28, 28)            0
#
# =================================================================
# Total params: 770084 (2.94 MB)
# Trainable params: 770084 (2.94 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt

# Plot del training loss
plt.style.use("ggplot")

plt.plot(np.arange(0, n_epochs), mfit.history["loss"], label="train")
plt.plot(np.arange(0, n_epochs), mfit.history["val_loss"], label="val")
plt.title("Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## 4. Visualización de los resultados
#
# Finalmente, presentaremos los resultados de aplicar el *autoencoder* en algunos ejemplos del conjunto de datos de test.

# %%
# codificamos y decodificamos las imágenes de test
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 313/313 [==============================] - 0s 278us/step
# 313/313 [==============================] - 0s 263us/step

# %% [markdown]
# Notese que este paso se puede realizar en un solo paso, empleando:
#
# > decoded_imgs = autoencoder.predict(x_test)

# %%
import matplotlib.pyplot as plt

n = 10  # cantidad de ejemplos que mostrar
plt.figure(figsize=(20, 4))

for i in range(n):
    # mostrar la imagen original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # mostrar la reconstrucción
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()
